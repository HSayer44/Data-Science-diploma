# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 10)}, font_scale=1.2)

# %%
df = pd.read_csv('sendy_logistics.csv')
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
df.isna().sum()
# Out:
# Order No                                         0
# User Id                                          0
# Vehicle Type                                     0
# Platform Type                                    0
# Personal or Business                             0
# Placement - Day of Month                         0
# Placement - Weekday (Mo = 1)                     0
# Placement - Time                                 0
# Confirmation - Day of Month                      0
# Confirmation - Weekday (Mo = 1)                  0
# Confirmation - Time                              0
# Arrival at Pickup - Day of Month                 0
# Arrival at Pickup - Weekday (Mo = 1)             0
# Arrival at Pickup - Time                         0
# Pickup - Day of Month                            0
# Pickup - Weekday (Mo = 1)                        0
# Pickup - Time                                    0
# Arrival at Destination - Day of Month            0
# ...

# %%
df.dropna(subset=['Temperature'], inplace=True)
df.isna().sum()
# Out:
# Order No                                         0
# User Id                                          0
# Vehicle Type                                     0
# Platform Type                                    0
# Personal or Business                             0
# Placement - Day of Month                         0
# Placement - Weekday (Mo = 1)                     0
# Placement - Time                                 0
# Confirmation - Day of Month                      0
# Confirmation - Weekday (Mo = 1)                  0
# Confirmation - Time                              0
# Arrival at Pickup - Day of Month                 0
# Arrival at Pickup - Weekday (Mo = 1)             0
# Arrival at Pickup - Time                         0
# Pickup - Day of Month                            0
# Pickup - Weekday (Mo = 1)                        0
# Pickup - Time                                    0
# Arrival at Destination - Day of Month            0
# ...

# %%
current_temperature = 14
def temp_difference(temp):
    return current_temperature - int(temp)
df['Temp_difference'] = df['Temperature'].apply(temp_difference)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# 5       Order_No_7408  User_Id_1342         Bike              3
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
# C*(9/5) + 32
def fah_temp(temp):
    return (temp * (9/5)) + 32

df['Fah_Temp'] = df['Temperature'].apply(fah_temp)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# 5       Order_No_7408  User_Id_1342         Bike              3
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
df = pd.read_csv('ufo.csv')
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%m/%d/%Y %H:%M', errors="coerce")
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
def is_december(date):
    return 1 if date.month == 12 else 0

df['IN_December'] = df['Time'].apply(is_december)
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time  IN_December
# 0     1930-06-01 22:00:00            0
# 1     1930-06-30 20:00:00            0
# 2     1931-02-15 14:00:00            0
# ...

# %%
from datetime import datetime
ww1 = datetime(1914, 7, 28)
df['Time_Diff_From_WW1'] = (df['Time'] - ww1) / np.timedelta64(1, 'Y')
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time  IN_December  Time_Diff_From_WW1
# 0     1930-06-01 22:00:00            0           15.846778
# 1     1930-06-30 20:00:00            0           15.925949
# ...

# %%
df = pd.read_csv('titanic_full.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def extract_title(name):
    if 'Mr.' in name:
        return 'Mr'
    elif 'Miss' in name:
        return 'Miss'
    elif 'Mrs' in name:
        return 'Mrs'
    else:
        return 'Untitled'

df['Title'] = df['Name'].apply(extract_title)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(x='Title', data=df)
# Out:
# <AxesSubplot:xlabel='Title', ylabel='count'>

# %%
df = pd.read_csv('sendy_logistics.csv')
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
def extract_user_id(user_id):
    return user_id.split('_')[2]

df['user_id'] = df['User Id'].apply(extract_user_id)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
df = pd.read_csv('visitor-interests.csv')
df
# Out:
#                    IP                                          UserAgent  \
# 0        1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 1         1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2       1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 3       1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...
# 4       1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# ...               ...                                                ...
# 19921      223.62.3.2  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19922   223.62.67.192  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19923   223.73.243.82  Mozilla/5.0 (Linux; U; Android 5.1.1; zh-cn; v...
# 19924    223.73.66.65  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...
# 19925  223.81.193.148  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
#
#       Country Languages                     Interests
# ...

# %%
import user_agents
def extract_data(ua):
    ua = user_agents.parse(ua)
    return pd.Series((ua.os.family, ua.browser.family, ua.device.family))

df[['OS', 'Browser', 'Device']] = df['UserAgent'].apply(extract_data)
df
# Out:
#                    IP                                          UserAgent  \
# 0        1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 1         1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2       1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 3       1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...
# 4       1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# ...               ...                                                ...
# 19921      223.62.3.2  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19922   223.62.67.192  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19923   223.73.243.82  Mozilla/5.0 (Linux; U; Android 5.1.1; zh-cn; v...
# 19924    223.73.66.65  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...
# 19925  223.81.193.148  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
#
#       Country Languages                     Interests        OS  \
# ...

# %%
from ip2geotools.databases.noncommercial import DbIpCity as ip2geo

def extract_lat_from_ip(ip):
    try:
        response = ip2geo.get(ip, api_key='free')
        return response.latitude
    except:
        return 'Unknown'

def extract_long_from_ip(ip):
    try:
        response = ip2geo.get(ip, appi_key='free')
        return response.longitude
    except:
        return 'Unknown'


df = pd.read_csv('visitor-interests.csv')
df = df.head(10)
df['Latitude'] = df['IP'].apply(extract_lat_from_ip)
df['Longitude'] = df['IP'].apply(extract_long_from_ip)
df
