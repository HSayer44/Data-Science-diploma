# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time
import csv

# %%
with open('messurment_log2.txt', 'w') as f:
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        temp = soup.find('div', attrs={'class': 'temp'}).get_text()
        temp = float(temp.split('°')[0])
        wind = float(soup.find('span', attrs={'class': 'white'}).find('b').get_text().strip())
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                pressure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")
        output = f"temp={temp}°C, wind={wind}°Km/h, humidity={humidity}%, visibility={visibility}m, pressure= mb at time {time_now}\n"
        f.write(output)
        print(f'scrappping done for {i+1} times at {time_now}')
        time.sleep(1)
# Out:
# scrappping done for 1 times at 01/11/2022 09:46:58
# scrappping done for 2 times at 01/11/2022 09:47:00
# scrappping done for 3 times at 01/11/2022 09:47:01
# scrappping done for 4 times at 01/11/2022 09:47:03
# scrappping done for 5 times at 01/11/2022 09:47:05
# scrappping done for 6 times at 01/11/2022 09:47:06
# scrappping done for 7 times at 01/11/2022 09:47:08
# scrappping done for 8 times at 01/11/2022 09:47:10
# scrappping done for 9 times at 01/11/2022 09:47:11
# scrappping done for 10 times at 01/11/2022 09:47:14

# %%
f = open('messurment_log2.txt', 'r')
print(f.read())
f.close()
# Out:
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:46:58
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:00
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:01
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:03
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:05
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:06
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:08
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:10
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:11
# temp=25.0°C, wind=7.0°Km/h, humidity=39.0%, visibility=2100.0m, pressure= mb at time 01/11/2022 09:47:14

# %%
import csv 

with open('messurments_log2.csv', 'w') as f:
    fnames = ['temp', 'wind', 'humidity', 'visibility', 'presure', 'time_now']
    writer = csv.DictWriter(f, fieldnames=fnames)
    writer.writeheader()
    for i in range(10):
        url = 'https://eg.freemeteo.com/weather/cairo/current-weather/location/?gid=360630&language=english&country=egypt'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        temp = soup.find('div', attrs={'class': 'temp'}).get_text()
        temp = float(temp.split('°')[0])
        wind = float(soup.find('span', attrs={'class': 'white'}).find('b').get_text().strip())
        stats = soup.find('div', attrs={'class': 'stats'}).get_text()
        for el in stats.split(' '):
            if el.endswith('%'):
                humidity = float(el.split('%')[0])
            elif el.endswith('m'):
                visibility = float(el.split('m')[0])
            elif el.endswith('mb'):
                presure = float(el.split('mb')[0])
        now = datetime.now()
        time_now = now.strftime("%d/%m/%Y %H:%M:%S")

        # Write to Txt file
        ############################################################################
        output = {'temp': temp, 'wind': wind, 'humidity': humidity, 'visibility': visibility, 'presure': 'unknown', 'time_now': time_now}
        writer.writerow(output)
        ############################################################################
        
        print(f'scrapping done for {i+1} times at {time_now}')
        time.sleep(1)

import pandas as pd
data = pd.read_csv('messurments_log2.csv')
data
# Out:
# scrapping done for 1 times at 01/11/2022 09:51:59
# scrapping done for 2 times at 01/11/2022 09:52:00
# scrapping done for 3 times at 01/11/2022 09:52:02
# scrapping done for 4 times at 01/11/2022 09:52:04
# scrapping done for 5 times at 01/11/2022 09:52:07
# scrapping done for 6 times at 01/11/2022 09:52:10
# scrapping done for 7 times at 01/11/2022 09:52:12
# scrapping done for 8 times at 01/11/2022 09:52:14
# scrapping done for 9 times at 01/11/2022 09:52:16
# scrapping done for 10 times at 01/11/2022 09:52:18
#    temp  wind  humidity  visibility  presure             time_now
# 0  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:51:59
# 1  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:00
# 2  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:02
# 3  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:04
# 4  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:07
# 5  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:10
# 6  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:12
# 7  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:14
# 8  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:16
# 9  25.0   7.0      39.0      2100.0  unknown  01/11/2022 09:52:18
