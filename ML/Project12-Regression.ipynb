# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize': [9,9]}, font_scale=1.2)

# %%
df = pd.read_csv('Ecommerce Customers.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
sns.distplot(df['Avg. Session Length'], bins=30)
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Avg. Session Length', ylabel='Density'>

# %%
sns.distplot(df['Time on App'], bins=30)
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Time on App', ylabel='Density'>

# %%
sns.distplot(df['Time on Website'], bins=30)
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Time on Website', ylabel='Density'>

# %%
sns.distplot(df['Length of Membership'], bins=30)
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length of Membership', ylabel='Density'>

# %%
sns.distplot(df['Yearly Amount Spent'], bins=30)
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
x = df[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
x
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y = df['Yearly Amount Spent']
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
models = {
    "LR": LinearRegression(),
    "KNNR": KNeighborsRegressor(),
    "SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
    "XGBR": XGBRegressor()
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Tese Score: {model.score(x_test, y_test)}')
    print('-'*30)
# Out:
# Using model: LR
# Training Score: 0.9843779068662921
# Tese Score: 0.984053557840393
# ------------------------------
# Using model: KNNR
# Training Score: 0.9375225909287463
# Tese Score: 0.9170920457033778
# ------------------------------
# Using model: SVR
# Training Score: 0.41550332339697305
# Tese Score: 0.3796792749428787
# ------------------------------
# Using model: DT
# Training Score: 1.0
# Tese Score: 0.8545963286879001
# ------------------------------
# Using model: RF
# Training Score: 0.9907160515048004
# Tese Score: 0.9299990233556764
# ------------------------------
# Using model: XGBR
# Training Score: 0.9999781329754628
# Tese Score: 0.962200269734729
# ------------------------------

# %%
model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([554.30140352, 535.58081357, 466.17234895, 467.29825838,
#        602.21970098, 429.50285237, 486.47296333, 500.69832757,
#        532.01008009, 558.56184304, 479.66767197, 429.26625091,
#        449.1616834 , 671.94066436, 543.64024721, 528.70578643,
#        460.5010048 , 521.23953696, 684.84472744, 563.82116123,
#        523.86788763, 503.83227218, 409.19484327, 495.02810664,
#        598.32918734, 398.48972768, 496.76879058, 434.65069254,
#        439.69295764, 474.71840648, 473.45451004, 606.90536638,
#        325.08939611, 716.2134163 , 619.13705025, 567.20020452,
#        315.73129422, 589.01696264, 576.42576756, 510.14667422,
#        551.74738951, 505.36469642, 503.78250524, 505.83588652,
#        455.78824464, 450.02547056, 570.63379071, 412.61162507,
#        519.15439484, 457.48284252, 588.79684706, 340.20094889,
#        551.95879261, 383.84555371, 397.85424416, 444.15577632,
#        394.09627983, 380.20250982, 476.24441354, 507.16916513,
# ...

# %%
y_test
# Out:
# 397    547.709989
# 465    543.132626
# 285    471.602884
# 412    444.053827
# 46     593.915003
#           ...
# 113    422.426776
# 455    438.303708
# 4      599.406092
# 15     461.780742
# 50     725.584814
# Name: Yearly Amount Spent, Length: 100, dtype: float64

# %%
x.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership'],
#       dtype='object')

# %%
custom_data = np.array([35, 13, 40, 4])

# %%
custom_data = scaler.transform([custom_data])
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(custom_data)
prediction
# Out:
# array([616.77437411])

# %%
import joblib

# %%
joblib.dump(model, 'model.h5')
# Out:
# ['model.h5']

# %%
joblib.dump(scaler, 'scaler.h5')
# Out:
# ['scaler.h5']
